# - ECI 26: https://citizens-initiative.europa.eu/initiatives/details/2022/000009_en European Citizens’ Initiative for VEGAN MEAL
# - ECI 27: https://citizens-initiative.europa.eu/initiatives/details/2022/000010_en European Day of "Whatever it Takes"
#
# ### Worldstat Kaggle Dataset
# https://www.kaggle.com/datasets/nelgiriyewithana/countries-of-the-world-2023
#
# ### 2023 Global Development and Prosperity Index
# https://www.kaggle.com/datasets/tarktunataalt/2023-global-country-development-and-prosperity-index
#
# ### Media Literacy Index Dataset 2023
# https://osis.bg/wp-content/uploads/2023/06/MLI-report-in-English-22.06.pdf
#
# https://osis.bg/?p=4450&lang=en
#
# ### Mahara Portfolio:
# https://mahara.dkit.ie/view/view.php?t=f816cb6da6dd833aaa2f
#
# ### Github Repository:
# https://github.com/Matthew-Riddell/MSc-Dissertation

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm

import scipy
from scipy import stats

from scipy.stats import kendalltau
from scipy.stats import spearmanr
from scipy.stats import pearsonr

# %% [markdown]
# ### Load dataset

# %%
file_path = "C:/Users/Matty/Documents/College Notes & Assignments/Year 5/Dissertation/MSc-Dissertation/data/Prepared Datasets/"
file_name = "master_dataset.csv"
complete_file_name = file_path + file_name

# %%
master = pd.read_csv(complete_file_name)

# %% [markdown]
# ### Dataset Overview

# %%
master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 729 entries, 0 to 728
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Petition_ID            729 non-null    object
#  1   Petition_Name          729 non-null    object
#  2   Country                729 non-null    object
#  3   Genre                  729 non-null    object
#  4   Year                   729 non-null    int64
#  5   Total_Signatures       729 non-null    int64
#  6   Successful             729 non-null    bool
#  7   Signatures             729 non-null    int64
#  8   Signatures_Per_Capita  729 non-null    float64
#  9   Population             729 non-null    float64
#  10  Population_Density     729 non-null    int64
#  11  GDP_Per_Capita         729 non-null    float64
#  12  Unemployment           729 non-null    float64
#  13  Tertiary_Enrollment    729 non-null    float64
#  14  Life_Expectancy        729 non-null    float64
#  15  Media_Literacy_Index   729 non-null    int64
#  16  Governance             729 non-null    float64
#  17  Social_Capital         729 non-null    float64
#  18  Personal_Freedom       729 non-null    float64
#  19  Education              729 non-null    float64
# dtypes: bool(1), float64(10), int64(5), object(4)
# memory usage: 109.0+ KB

# %%
master.describe()
# Out:
#               Year  Total_Signatures     Signatures  Signatures_Per_Capita  \
# count   729.000000      7.290000e+02     729.000000             729.000000
# mean   2023.037037      3.041736e+05   11265.687243               0.000796
# std       0.793171      4.721613e+05   50819.605979               0.002519
# min    2022.000000      2.540000e+02       0.000000               0.000000
# 25%    2022.000000      4.432000e+03      32.000000               0.000005
# 50%    2023.000000      2.141000e+04     175.000000               0.000019
# 75%    2024.000000      5.903680e+05    2006.000000               0.000251
# max    2024.000000      1.502319e+06  841188.000000               0.033544
#
#          Population  Population_Density  GDP_Per_Capita  Unemployment  \
# count  7.290000e+02          729.000000      729.000000    729.000000
# mean   1.657809e+07          176.592593    34820.662358      6.042593
# std    2.187871e+07          259.201972    22196.385563      3.238102
# min    5.026530e+05           18.000000    12328.404026      1.930000
# 25%    2.786844e+06           72.000000    19329.096801      3.980000
# 50%    8.877067e+06          109.000000    25739.247814      5.360000
# 75%    1.733285e+07          139.000000    48685.853987      6.590000
# max    8.313280e+07         1380.000000   110172.373141     17.240000
#
#        Tertiary_Enrollment  Life_Expectancy  Media_Literacy_Index  Governance  \
# count           729.000000       729.000000            729.000000  729.000000
# mean             71.255556        79.907407             54.555556   71.645185
# std              19.903749         2.706301             11.872607   12.080811
# min              19.200000        74.700000             31.000000   45.750000
# 25%              63.900000        77.600000             45.000000   61.930000
# 50%              70.200000        81.000000             55.000000   72.480000
# 75%              80.600000        82.100000             61.000000   81.720000
# max             136.600000        83.300000             74.000000   90.410000
#
#        Social_Capital  Personal_Freedom   Education
# count      729.000000        729.000000  729.000000
# mean        63.160000         81.348889   80.451852
# std          8.453254          8.128053    4.449479
# min         47.260000         60.360000   70.470000
# 25%         56.860000         75.800000   78.330000
# 50%         62.690000         81.390000   80.980000
# 75%         67.940000         87.700000   83.450000
# max         82.560000         94.090000   88.380000

# %%
print(f"Rows: {master.shape[0]}")
print(f"Columns: {master.shape[1]}")

print(f"Countries: {master['Country'].nunique()}")
print(f"Petitions: {master['Petition_ID'].nunique()}")
# Out:
# Rows: 729
# Columns: 20
# Countries: 27
# Petitions: 27

# %% [markdown]
# This dataset contains a total of 27 petitions across 2022, 2023, 2024
#
# with 27 EU member states this brings a total of 27 x 27 observations
#
# A total of 729 rows
#
# 19 columns comprised of variables retrived from the country level world stat data, media literacy index, petition level data and the prosperity and development dataset
#
# The final dataset contains the following variables:
#
# - "Petition_ID" = Unique identifier for each Initiative (string)
# - "Petition_Name" = Name of the Initiative (String) Categorical
# - "Country" = Name of the country (String) Categorical
# - "Genre" = Genre of Initiative (String) Categorical
# - "Year" = Year of the Initiative (Int) Discreet
# - "Total_Signatures" = Total signatures collected per Initiative (Int) Discreet
# - "Successful" = True/False of the Initiative succesfully passed (Boolean) Discreet
# - "Signatures" = Number of collected Signatures (Int) Discreet
# - "Signatures_Per_Capita" = Signatures / Population per country (Float) Continuous
# - "Population" = Population of the country (int) Discreet
# - "Population_Density" = Population per km squared per country (float) Continuous
# - "GDP_Per_Capita" = Gross Domestic Product / Population per country (float) continuous
# - "Unemployment" = Rate of unemployment per country (float) continuous
# - "Tertiary_Enrollment" = Rate of third level enrollment per country (float) continuous
# - "Life_Expectancy" = Estimate average life expectancy in years (float) continous
# - "Media_Literacy_Index" = Combined index that measures internet and social media use and media activity per country (float) continuous
# - "Governance" = Measure of Quality of democracy, rule of law, and government effectiveness per country (float) continuous
# - "Social_Capital" = Measure of Strength of personal relationships and civic engagement per country (float) continuous
# - "Personal_Freedom" = Measure of Rights to speech, assembly, and individual autonomy per country (float) continuous
# - "Education" = Measure of Quality and accessibility of education per country (float) continuous

# %% [markdown]
# ### Distribution of Variables

# %% [markdown]
# Below are Histograms of each numerical variable in the dataset
#
# This time around for readability sake I decided to create the Histograms in one graphic instead of doing it one by one like I did during my Interim Report which made the file really long and harder to scroll through, this will keep it much cleaner.

# %%
# Code adapted from
# https://medium.com/data-science/a-hidden-gem-df-select-dtypes-a660db0e8609

numeric = master.select_dtypes(include="number")

numeric.hist(figsize=(16,12))
# Out:
# array([[<Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Total_Signatures'}>,
#         <Axes: title={'center': 'Signatures'}>,
#         <Axes: title={'center': 'Signatures_Per_Capita'}>],
#        [<Axes: title={'center': 'Population'}>,
#         <Axes: title={'center': 'Population_Density'}>,
#         <Axes: title={'center': 'GDP_Per_Capita'}>,
#         <Axes: title={'center': 'Unemployment'}>],
#        [<Axes: title={'center': 'Tertiary_Enrollment'}>,
#         <Axes: title={'center': 'Life_Expectancy'}>,
#         <Axes: title={'center': 'Media_Literacy_Index'}>,
#         <Axes: title={'center': 'Governance'}>],
#        [<Axes: title={'center': 'Social_Capital'}>,
#         <Axes: title={'center': 'Personal_Freedom'}>,
#         <Axes: title={'center': 'Education'}>, <Axes: >]], dtype=object)

# %% [markdown]
# ### Country Participation Analysis

# %%
country = (
    master
    .groupby("Country")["Signatures_Per_Capita"]
    .mean()
    .sort_values(ascending=False)
)

country.plot.bar(figsize=(14,6))
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# ### Petition Analysis

# %%
petition = (
    master
    .groupby("Petition_Name")["Total_Signatures"]
    .first()
    .sort_values()
)

petition.plot.bar(figsize=(14,6))
# Out:
# <Axes: xlabel='Petition_Name'>

# %% [markdown]
# ### Genre Analysis

# %%
genreplot = (
    master
    .groupby("Genre")["Total_Signatures"]
    .mean()
    .sort_values()
)

genreplot.plot.bar(figsize=(14,6))
# Out:
# <Axes: xlabel='Genre'>

# %% [markdown]
# ### Correlation Matrices

# %%
print("\nPearson correlation matrix:")
pearson_corr = numeric.corr(method='pearson', numeric_only=True)
display(pearson_corr)

print("\nSpearman correlation matrix:")
spearman_corr = numeric.corr(method='spearman', numeric_only=True)
display(spearman_corr)

print("\nKendall's Tau correlation matrix:")
kendall_corr = numeric.corr(method='kendall', numeric_only=True)
display(kendall_corr)
# Out:
# Pearson correlation matrix:
#                                Year  Total_Signatures  Signatures  \
# Year                   1.000000e+00      2.149744e-01    0.073975
# Total_Signatures       2.149744e-01      1.000000e+00    0.344108
# Signatures             7.397452e-02      3.441085e-01    1.000000
# Signatures_Per_Capita  5.927182e-02      5.389551e-01    0.424824
# Population            -4.346551e-15     -1.214787e-16    0.313850
# Population_Density     4.915811e-15     -1.133939e-16   -0.003723
# GDP_Per_Capita         7.987366e-16     -2.941155e-16    0.038111
# Unemployment          -8.182237e-15     -2.534522e-16    0.050222
# Tertiary_Enrollment   -1.312214e-16      1.702946e-16   -0.001874
# Life_Expectancy       -8.701067e-15     -2.301285e-15    0.115043
# Media_Literacy_Index  -8.378092e-15     -5.333238e-16    0.039027
# Governance             3.903713e-16      8.793851e-16    0.059092
# Social_Capital        -9.104592e-15      4.019314e-16    0.032748
# Personal_Freedom      -4.945624e-15     -3.475104e-16    0.025888
# Education             -2.789410e-15      1.490667e-15    0.063144
#
#                        Signatures_Per_Capita    Population  \
# Year                                0.059272 -4.346551e-15
# Total_Signatures                    0.538955 -1.214787e-16
# Signatures                          0.424824  3.138501e-01
# Population_Density                  0.024540    0.185185            1.000000
# GDP_Per_Capita                      0.084512    0.014245            0.225071
# Unemployment                        0.028392   -0.051355           -0.245364
# Tertiary_Enrollment                 0.017946    0.037037           -0.196581
# Life_Expectancy                     0.077997    0.160693            0.235300
# Media_Literacy_Index                0.039796    0.048852           -0.031610
# Governance                          0.065307   -0.025641            0.094017
# Social_Capital                      0.050585    0.037037            0.213675
# Personal_Freedom                    0.054097   -0.057061            0.068474
# Education                           0.048985    0.079886           -0.045649
#
#                        GDP_Per_Capita  Unemployment  Tertiary_Enrollment  \
# Year                         0.000000      0.000000             0.000000
# Total_Signatures             0.000000      0.000000             0.000000
# Signatures                   0.072635      0.026862             0.031070
# Signatures_Per_Capita        0.084512      0.028392             0.017946
# Population                   0.014245     -0.051355             0.037037
# Population_Density           0.225071     -0.245364            -0.196581
# GDP_Per_Capita               1.000000     -0.017118             0.145299
# Unemployment                -0.017118      1.000000             0.194009
# Tertiary_Enrollment          0.145299      0.194009             1.000000
# Life_Expectancy              0.562425      0.221268             0.109042
# Media_Literacy_Index         0.560366     -0.040289             0.244262
# Governance                   0.720798     -0.022825             0.230769
# Social_Capital               0.612536     -0.142653             0.156695
# Personal_Freedom             0.656206     -0.014286             0.194009
# Education                    0.582026      0.008571             0.422254
#
#                        Life_Expectancy  Media_Literacy_Index  Governance  \
# Year                          0.000000              0.000000    0.000000
# Total_Signatures              0.000000              0.000000    0.000000
# Signatures                    0.130214              0.065031    0.040078
# Signatures_Per_Capita         0.077997              0.039796    0.065307
# Population                    0.160693              0.048852   -0.025641
# Population_Density            0.235300             -0.031610    0.094017
# GDP_Per_Capita                0.562425              0.560366    0.720798
# Unemployment                  0.221268             -0.040289   -0.022825
# Tertiary_Enrollment           0.109042              0.244262    0.230769
# Life_Expectancy               1.000000              0.289436    0.373037
# Media_Literacy_Index          0.289436              1.000000    0.698302
# Governance                    0.373037              0.698302    1.000000
# Social_Capital                0.487817              0.571860    0.572650
# Personal_Freedom              0.341960              0.739587    0.833096
# Education                     0.313224              0.684910    0.684737
#
#                        Social_Capital  Personal_Freedom  Education
# Year                         0.000000          0.000000   0.000000
# Total_Signatures             0.000000          0.000000   0.000000
# Signatures                   0.057517          0.017510   0.061197
# Signatures_Per_Capita        0.050585          0.054097   0.048985
# Population                   0.037037         -0.057061   0.079886
# Population_Density           0.213675          0.068474  -0.045649
# GDP_Per_Capita               0.612536          0.656206   0.582026
# Unemployment                -0.142653         -0.014286   0.008571
# Tertiary_Enrollment          0.156695          0.194009   0.422254
# Life_Expectancy              0.487817          0.341960   0.313224
# Media_Literacy_Index         0.571860          0.739587   0.684910
# Governance                   0.572650          0.833096   0.684737
# Social_Capital               1.000000          0.587732   0.467903
# Personal_Freedom             0.587732          1.000000   0.625714
# Education                    0.467903          0.625714   1.000000

# %%
plt.figure(figsize=(12,10))

sns.heatmap(
    pearson_corr,
    annot=True,
    cmap="coolwarm",
    center=0
)

plt.figure(figsize=(12,10))

sns.heatmap(
    spearman_corr,
    annot=True,
    cmap="coolwarm",
    center=0
)

plt.figure(figsize=(12,10))

sns.heatmap(
    kendall_corr,
    annot=True,
    cmap="coolwarm",
    center=0
)
# Out:
# <Axes: >

# %%
target_corr = pearson_corr["Signatures_Per_Capita"].sort_values()

# %% [markdown]
# ### Scatterplots

# %% [markdown]
# #### GDP Per Capita vs Signatures Per Capita

# %%
sns.regplot(
    data=master,
    x="GDP_Per_Capita",
    y="Signatures_Per_Capita"
)
# Out:
# <Axes: xlabel='GDP_Per_Capita', ylabel='Signatures_Per_Capita'>

# %% [markdown]
# #### Media Literacy Index vs Signatures Per Capita

# %%
sns.regplot(
    data=master,
    x="Media_Literacy_Index",
    y="Signatures_Per_Capita"
)
# Out:
# <Axes: xlabel='Media_Literacy_Index', ylabel='Signatures_Per_Capita'>

# %% [markdown]
# #### Governance vs Signatures Per Capita

# %%
sns.regplot(
    data=master,
    x="Governance",
    y="Signatures_Per_Capita"
)
# Out:
# <Axes: xlabel='Governance', ylabel='Signatures_Per_Capita'>

# %% [markdown]
# #### Education vs Signatures Per Capita

# %%
sns.regplot(
    data=master,
    x="Education",
    y="Signatures_Per_Capita"
)
# Out:
# <Axes: xlabel='Education', ylabel='Signatures_Per_Capita'>

# %% [markdown]
# #### Social Capital vs Signatures Per Capita

# %%
sns.regplot(
    data=master,
    x="Social_Capital",
    y="Signatures_Per_Capita"
)
# Out:
# <Axes: xlabel='Social_Capital', ylabel='Signatures_Per_Capita'>

# %% [markdown]
# ### Boxplots

# %%
for col in numeric.columns:

    plt.figure(figsize=(6,1.5))

    sns.boxplot(x=master[col])

    plt.title(col)

    plt.show()

# %% [markdown]
# ### Pairplots

# %%
sns.pairplot(
    master[
        [
            "Signatures_Per_Capita",
            "GDP_Per_Capita",
            "Media_Literacy_Index",
            "Governance",
            "Education"
        ]
    ]
)

# %% [markdown]
# ### Initiative Success Analysis

# %%
master.groupby("Successful")["Signatures_Per_Capita"].mean()
# Out:
# Successful
# False    0.000254
# True     0.003913
# Name: Signatures_Per_Capita, dtype: float64

# %%
sns.boxplot(
    data=master,
    x="Successful",
    y="Signatures_Per_Capita"
)
# Out:
# <Axes: xlabel='Successful', ylabel='Signatures_Per_Capita'>

# %% [markdown]
# ### Genre Analysis

# %%
sns.boxplot(
    data=master,
    x="Genre",
    y="Signatures_Per_Capita"
)
# Out:
# <Axes: xlabel='Genre', ylabel='Signatures_Per_Capita'>

# %% [markdown]
# ### Summary of Correlations with Signatures Per Capita

# %%
corr = (
    master
    .corr(numeric_only=True)["Signatures_Per_Capita"]
    .sort_values(ascending=False)
)

print(corr)
# Out:
# Signatures_Per_Capita    1.000000
# Total_Signatures         0.538955
# Successful               0.516317
# Signatures               0.424824
# Education                0.085760
# Media_Literacy_Index     0.081737
# Governance               0.081142
# Personal_Freedom         0.077191
# GDP_Per_Capita           0.067263
# Social_Capital           0.064914
# Year                     0.059272
# Life_Expectancy          0.025730
# Tertiary_Enrollment      0.012949
# Population_Density       0.008931
# Unemployment            -0.011039
# Population              -0.034992
# Name: Signatures_Per_Capita, dtype: float64
