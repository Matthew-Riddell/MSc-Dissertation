# %% [markdown]
# ### Matthew Riddell
# ### D00245674
# ### MSc in Data Analytics
# ### Dissertation
# ### Model Results Jupyter Notebook
#
# Summary of each model I created for the Dissertation
#
# In this file I import each model that was created in the project and show the summary results of each
#
# I then evaluate each model and my overall observations of the models and their performance in relation to the Research Questions
#
#
# ### Link to each Dataset:
#
# ### ECI Petitions:
# #### 2024
#
# - ECI 01: https://citizens-initiative.europa.eu/initiatives/details/2024/000001_en Ban on conversion practices in the European Union
# - ECI 02: https://citizens-initiative.europa.eu/initiatives/details/2024/000002_en European Citizens' Initiative in Defence of Agriculture and Rural Economy in Europe
# - ECI 03: https://citizens-initiative.europa.eu/initiatives/details/2024/000004_en My Voice, My Choice: For Safe And Accessible Abortion
# - ECI 04: https://citizens-initiative.europa.eu/initiatives/details/2024/000006_en Air-Quotas
# - ECI 05: https://citizens-initiative.europa.eu/initiatives/details/2024/000007_en Stop Destroying Videogames
# - ECI 06: https://citizens-initiative.europa.eu/initiatives/details/2024/000008_en Stop Cruelty Stop Slaughter
# - ECI 07: https://citizens-initiative.europa.eu/initiatives/details/2024/000009_en STOP FAKE FOOD: ORIGIN ON LABEL
# - ECI 08: https://citizens-initiative.europa.eu/initiatives/details/2024/000010_en ECI for a Water-Smart and Resilient Europe
# - ECI 09: https://citizens-initiative.europa.eu/initiatives/details/2024/000011_en PsychedeliCare
#
# #### 2023
#
# - ECI 10: https://citizens-initiative.europa.eu/initiatives/details/2023/000001_en Stop torture and inhuman treatment at Europe’s borders
# - ECI 11: https://citizens-initiative.europa.eu/initiatives/details/2023/000002_en Ensuring a dignified reception of migrants in Europe
# - ECI 12: https://citizens-initiative.europa.eu/initiatives/details/2023/000003_en End The Horse Slaughter Age
# - ECI 13: https://citizens-initiative.europa.eu/initiatives/details/2023/000004_en Connecting all European capitals and people through a high-speed train network
# - ECI 14: https://citizens-initiative.europa.eu/initiatives/details/2023/000005_en Effective implementation of the concept of judicial precedent in EU countries
# - ECI 15: https://citizens-initiative.europa.eu/initiatives/details/2023/000006_en Taxing great wealth to finance the ecological and social transition
# - ECI 16: https://citizens-initiative.europa.eu/initiatives/details/2023/000007_en Preservation and development of Ukrainian culture, education, language, and traditions in EU states
# - ECI 17: https://citizens-initiative.europa.eu/initiatives/details/2023/000008_en EU Live Bus Stop Info
# - ECI 18: https://citizens-initiative.europa.eu/initiatives/details/2023/000009_en Trust and Freedom
# - ECI 19: https://citizens-initiative.europa.eu/initiatives/details/2023/000011_en Creation of a European Environment Authority
#
# #### 2022
#
# - ECI 20: https://citizens-initiative.europa.eu/initiatives/details/2022/000001_en Win It On The Pitch
# - ECI 21: https://citizens-initiative.europa.eu/initiatives/details/2022/000002_en Fur Free Europe
# - ECI 22: https://citizens-initiative.europa.eu/initiatives/details/2022/000003_en End The Slaughter Age
# - ECI 23: https://citizens-initiative.europa.eu/initiatives/details/2022/000004_en Good Clothes, Fair Pay
# - ECI 24: https://citizens-initiative.europa.eu/initiatives/details/2022/000007_en Protect the EU’s Rural Heritage, Food Security and Supply
# - ECI 25: https://citizens-initiative.europa.eu/initiatives/details/2022/000008_en Focus on Specific Learning Disabilities on EU Level
# - ECI 26: https://citizens-initiative.europa.eu/initiatives/details/2022/000009_en European Citizens’ Initiative for VEGAN MEAL
# - ECI 27: https://citizens-initiative.europa.eu/initiatives/details/2022/000010_en European Day of "Whatever it Takes"
#
# ### Worldstat Kaggle Dataset
# https://www.kaggle.com/datasets/nelgiriyewithana/countries-of-the-world-2023
#
# ### 2023 Global Development and Prosperity Index
# https://www.kaggle.com/datasets/tarktunataalt/2023-global-country-development-and-prosperity-index
#
# ### Media Literacy Index Dataset 2023
# https://osis.bg/wp-content/uploads/2023/06/MLI-report-in-English-22.06.pdf
#
# https://osis.bg/?p=4450&lang=en
#
# ### Mahara Portfolio:
# https://mahara.dkit.ie/view/view.php?t=f816cb6da6dd833aaa2f
#
# ### Github Repository:
# https://github.com/Matthew-Riddell/MSc-Dissertation

# %% [markdown]
# ### Import Libraries

# %%
import os
import joblib
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Model Path

# %%
model_path = r"C:/Users/Matty/Documents/College Notes & Assignments/Year 5/Dissertation/MSc-Dissertation/models/"

# %% [markdown]
# ## Linear Regressions 1: Raw Signatures
#
# Can socio-economic indicators explain raw signature counts?
#
#
# #### Hypotheses:
#
# H0
#
# Socio-economic indicators do not explain a significant proportion of the variation in raw signature counts
#
# H1
#
# Socio-economic indicators indicators explain a limited portion of the variation in raw signature counts

# %% [markdown]
# ### Linear Regression Model 1A - Raw Signatures

# %%
model_1a = joblib.load(model_path + "regressions/regression_model_1a.pkl")

print("=" * 100)
print("Linear Regression Model 1A - Raw Signatures")
print("=" * 100)
print(model_1a.summary())
print("\n")
# Out:
# ...
# Linear Regression Model 1A - Raw Signatures
# ...
#                             OLS Regression Results
# ...
# Dep. Variable:             Signatures   R-squared:                       0.100
# Model:                            OLS   Adj. R-squared:                  0.097
# Method:                 Least Squares   F-statistic:                     40.29
# Date:                Fri, 28 Aug 2026   Prob (F-statistic):           2.55e-17
# Time:                        01:09:51   Log-Likelihood:                -8895.0
# No. Observations:                 729   AIC:                         1.780e+04
# Df Residuals:                     726   BIC:                         1.781e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Interpretations
#
# P Value of Population < 0.05
#
# P value of GDP per Capita > 0.05
#
# - R Squared: 0.09990934679949715
#
# - Adjusted R Squared: 0.09742975822318733
#
# - F-statistic: 40.29271136108406
#
# - Model p-value: 2.546299206164381e-17
#
# - RMSE: 48181.059394702716
#
# - MAE: 16630.70023552485
#
# This model explains roughly 10% of variance in Signatures
#
# The model is high;y significant as the p values < 0.05
#
# THe model predictions differ by roughly 48181 signatures
#
# The model deviates from target values by about 16630 signatures
#
# This model shows that GDP per Capita and Population explain 10% of the variance in raw signatures
#
# And due to the p value of the model < 0.05 it rejects H0 of Research Question 1

# %% [markdown]
# ### Linear Regression Model 1B - Raw Signatures

# %%
model_1b = joblib.load(model_path + "regressions/regression_model_1b.pkl")

print("=" * 100)
print("Linear Regression Model 1B - Raw Signatures")
print("=" * 100)
print(model_1b.summary())
print("\n")
# Out:
# ...
# Linear Regression Model 1B - Raw Signatures
# ...
#                             OLS Regression Results
# ...
# Dep. Variable:             Signatures   R-squared:                       0.099
# Model:                            OLS   Adj. R-squared:                  0.094
# Method:                 Least Squares   F-statistic:                     19.97
# Date:                Fri, 28 Aug 2026   Prob (F-statistic):           1.30e-15
# Time:                        01:09:51   Log-Likelihood:                -8895.2
# No. Observations:                 729   AIC:                         1.780e+04
# Df Residuals:                     724   BIC:                         1.782e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Interpretations
#
# P Value of Population < 0.05
#
# P Value of Population_Density > 0.05
#
# P Value of Tertiary_Enrollment > 0.05
#
# P Value of Life_Expectancy > 0.05
#
# - R Squared: 0.09937624969017278
#
# - Adjusted R Squared: 0.09440042786525649
#
# - F-statistic: 19.971826401128602
#
# - Model p-value: 1.2960089454592907e-15
#
# - RMSE: 48195.32539189874
#
# - MAE: 16598.140993771223
#
# This model explains roughly 10% of variance in Signatures
#
# The model is highly significant as the p value is < 0.05
#
# THe model predictions differ by roughly 48195 signatures
#
# The model deviates from target values by about 16598 signatures
#
# This model shows that Popluation, Population Density, Tertiary Enrollment and Life Expectancy explain roughly 10% of the variance in raw signatures
#
# And due to the p value of the model < 0.05 it rejects H0 of Research Question 1

# %% [markdown]
# ### Linear Regression Model 1C - Raw Signatures

# %%
model_1c = joblib.load(model_path + "regressions/regression_model_1c.pkl")

print("=" * 100)
print("Linear Regression Model 1C - Raw Signatures")
print("=" * 100)
print(model_1c.summary())
print("\n")
# Out:
# ...
# Linear Regression Model 1C - Raw Signatures
# ...
#                             OLS Regression Results
# ...
# Dep. Variable:             Signatures   R-squared:                       0.101
# Model:                            OLS   Adj. R-squared:                  0.094
# Method:                 Least Squares   F-statistic:                     13.57
# Date:                Fri, 28 Aug 2026   Prob (F-statistic):           1.26e-14
# Time:                        01:09:51   Log-Likelihood:                -8894.4
# No. Observations:                 729   AIC:                         1.780e+04
# Df Residuals:                     722   BIC:                         1.784e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Interpretations
#
# P Value of Population < 0.05
#
# P Value of Media Literacy Index > 0.05
#
# P Value of Governance > 0.05
#
# P Value of Social_Capital > 0.05
#
# P Value of Personal Freedom > 0.05
#
# P Value of Education > 0.05
#
# - R Squared: 0.10132061322787378
#
# - Adjusted R Squared: 0.09385236347630499
#
# - F-statistic: 13.566848538586772
#
# - Model p-value: 1.2635107383049087e-14
#
# - RMSE: 48143.27265322001
#
# - MAE: 16649.580577972207
#
# This model explains roughly 10% of variance in Signatures
#
# The model is highly significant as the p value is < 0.05
#
# THe model predictions differ by roughly 48143 signatures
#
# The model deviates from target values by about 16649 signatures
#
# This model shows that Population, Media Literacy Index, Governance, Social Capital, Personal Freedom and Education explain roughly 10% of the variance in raw signatures
#
# And due to the p value of the model < 0.05 it rejects H0 of Research Question 1

# %% [markdown]
# ## Linear Regressions 2: Signatures Per Capita
#
# Can socio-economic indicators explain participation rates?
#
# #### Hypotheses:
#
# H0
#
# Socio-economic indicators have no significant relationship with participation rates when participation is normalised by population
#
# H1
#
# Socio-economic indicators have a limited explanatory power when participation is normalised by population

# %% [markdown]
# ### Linear Regression Model 2A - Signatures Per Capita

# %%
model_2a = joblib.load(model_path + "regressions/regression_model_2a.pkl")

print("=" * 100)
print("Linear Regression Model 2A - Signatures Per Capita")
print("=" * 100)
print(model_2a.summary())
print("\n")
# Out:
# ...
# Linear Regression Model 2A - Signatures Per Capita
# ...
#                               OLS Regression Results
# ...
# Dep. Variable:     Signatures_Per_Capita   R-squared:                       0.005
# Model:                               OLS   Adj. R-squared:                  0.002
# Method:                    Least Squares   F-statistic:                     1.656
# Date:                   Fri, 28 Aug 2026   Prob (F-statistic):              0.192
# Time:                           01:09:51   Log-Likelihood:                 3329.9
# No. Observations:                    729   AIC:                            -6654.
# Df Residuals:                        726   BIC:                            -6640.
# Df Model:                              2
# Covariance Type:               nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Interpretations
#
# P value of GDP per Capita > 0.05
#
# P value of Unemployment > 0.05
#
# - R Squared: 0.004540913652041678
#
# - Adjusted R Squared: 0.001798602119402748
#
# - F-statistic: 1.6558708221132903
#
# - Model p-value: 0.1916459661657725
#
# - RMSE: 0.0025119420544639564
#
# - MAE: 0.001186789429744381
#
# This model explains roughly 0.45% of variance in Signatures Per Capita
#
# The model performs poorly and is insignificant as the p value is > 0.05
#
# GDP per Capita and Unemployment poorly explain variance in Signatures Per Capita in this Model
#
# And due to the p value of the model > 0.05 it fails to reject H0 of Research Question 2

# %% [markdown]
# ### Linear Regression Model 2B - Signatures Per Capita

# %%
model_2b = joblib.load(model_path + "regressions/regression_model_2b.pkl")

print("=" * 100)
print("Linear Regression Model 2B - Signatures Per Capita")
print("=" * 100)
print(model_2b.summary())
print("\n")
# Out:
# ...
# Linear Regression Model 2B - Signatures Per Capita
# ...
#                               OLS Regression Results
# ...
# Dep. Variable:     Signatures_Per_Capita   R-squared:                       0.007
# Model:                               OLS   Adj. R-squared:                 -0.000
# Method:                    Least Squares   F-statistic:                    0.9846
# Date:                   Fri, 28 Aug 2026   Prob (F-statistic):              0.426
# Time:                           01:09:51   Log-Likelihood:                 3330.7
# No. Observations:                    729   AIC:                            -6649.
# Df Residuals:                        723   BIC:                            -6622.
# Df Model:                              5
# Covariance Type:               nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Interpretations
#
# P Value of GDP_Per_Capita > 0.05
#
# P Value of Unemployment > 0.05
#
# P Value of Tertiary_Enrollment > 0.05
#
# P Value of Life_Expectancy > 0.05
#
# P Value of Population_Density > 0.05
#
# - R Squared: 0.006762903327590886
#
# - Adjusted R Squared: -0.00010595626212150933
#
# - F-statistic: 0.9845744026737415
#
# - Model p-value: 0.4261737620421674
#
# - RMSE: 0.0025091370032440706
#
# - MAE: 0.0011877750463887542
#
# This model explains roughly 0.67% of variance in Signatures Per Capita
#
# The model performs poorly and is insignificant as the p value is > 0.05
#
# GDP per Capita, Unemployment Tertiary Enrollment, LIfe Expectancy and Population Density poorly explain variance in Signatures Per Capita in this model
#
# And due to the p value of the model > 0.05 it fails to reject H0 of Research Question 2

# %% [markdown]
# ### Linear Regression Model 2C - Signatures Per Capita

# %%
model_2c = joblib.load(model_path + "regressions/regression_model_2c.pkl")

print("=" * 100)
print("Linear Regression Model 2C - Signatures Per Capita")
print("=" * 100)
print(model_2c.summary())
print("\n")
# Out:
# ...
# Linear Regression Model 2C - Signatures Per Capita
# ...
#                               OLS Regression Results
# ...
# Dep. Variable:     Signatures_Per_Capita   R-squared:                       0.008
# Model:                               OLS   Adj. R-squared:                  0.001
# Method:                    Least Squares   F-statistic:                     1.157
# Date:                   Fri, 28 Aug 2026   Prob (F-statistic):              0.329
# Time:                           01:09:51   Log-Likelihood:                 3331.1
# No. Observations:                    729   AIC:                            -6650.
# Df Residuals:                        723   BIC:                            -6623.
# Df Model:                              5
# Covariance Type:               nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Interpretations
#
# P Value of Media Literacy Index > 0.05
#
# P Value of Governance > 0.05
#
# P Value of Social Capital > 0.05
#
# P Value of Personal Freedom > 0.05
#
# P Value of Education > 0.05
#
# - R Squared: 0.0079352755410812
#
# - Adjusted R Squared: 0.0010745236430250715
#
# - F-statistic: 1.1566189331710908
#
# - Model p-value: 0.3290380642093612
#
# - RMSE: 0.0025076557300060536
#
# - MAE: 0.0011881254635765293
#
# This model explains roughly 0.79% of variance in Signatures Per Capita
#
# The model performs poorly and is insignificant as the p value is > 0.05
#
# Media Literacy Index, Governance, Social Capital, Personal Freedom and Education poorly explain variance in signatures per capita in this model
#
# And due to the p value of the model > 0.05 it fails to reject H0 of Research Question 2

# %% [markdown]
# ## Linear Regressions 3: Signatures Per Capita (Successful ECI Petitions only)
#
# Can socio-economic indicators explain participation rates when the analysis is reduced to only successful Petitions?
#
# #### Hypotheses:
#
# H0
#
# Socio-economic indicators have no significant relationship with participation rates when participation is normalised by population
#
# H1
#
# Socio-economic indicators have a limited explanatory power when participation is normalised by population

# %% [markdown]
# ### Linear Regression Model 3A - Successful Petitions

# %%
model_3a = joblib.load(model_path + "regressions/regression_model_3a.pkl")

print("=" * 100)
print("Linear Regression Model 3A - Successful Petitions")
print("=" * 100)
print(model_3a.summary())
print("\n")
# Out:
# ...
# Linear Regression Model 3A - Successful Petitions
# ...
#                               OLS Regression Results
# ...
# Dep. Variable:     Signatures_Per_Capita   R-squared:                       0.003
# Model:                               OLS   Adj. R-squared:                 -0.016
# Method:                    Least Squares   F-statistic:                    0.1490
# Date:                   Fri, 28 Aug 2026   Prob (F-statistic):              0.862
# Time:                           01:09:51   Log-Likelihood:                 420.12
# No. Observations:                    108   AIC:                            -834.2
# Df Residuals:                        105   BIC:                            -826.2
# Df Model:                              2
# Covariance Type:               nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Interpretations
#
# P value of GDP per Capita > 0.05
#
# P value of Unemployment > 0.05
#
# - R Squared: 0.0028302050507570398
#
# - Adjusted R Squared: -0.01616350532922839
#
# - F-statistic: 0.14900748690678955
#
# - Model p-value: 0.8617445251109912
#
# - RMSE: 0.004947186712620768
#
# - MAE: 0.002898052335851381
#
# This model explains roughly 0.28% of variance in Signatures Per Capita
#
# The model performs poorly and is insignificant as the p value is > 0.05
#
# GDP per Capita and Unemployment poorly explain variance in signatures per capita in this model
#
# And due to the p value of the model > 0.05 it fails to reject H0 of Research Question 3

# %% [markdown]
# ### Linear Regression Model 3B - Successful Petitions

# %%
model_3b = joblib.load(model_path + "regressions/regression_model_3b.pkl")

print("=" * 100)
print("Linear Regression Model 3B - Successful Petitions")
print("=" * 100)
print(model_3b.summary())
print("\n")
# Out:
# ...
# Linear Regression Model 3B - Successful Petitions
# ...
#                               OLS Regression Results
# ...
# Dep. Variable:     Signatures_Per_Capita   R-squared:                       0.033
# Model:                               OLS   Adj. R-squared:                 -0.015
# Method:                    Least Squares   F-statistic:                    0.6940
# Date:                   Fri, 28 Aug 2026   Prob (F-statistic):              0.629
# Time:                           01:09:51   Log-Likelihood:                 421.77
# No. Observations:                    108   AIC:                            -831.5
# Df Residuals:                        102   BIC:                            -815.5
# Df Model:                              5
# Covariance Type:               nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Interpretations
#
# P Value of GDP_Per_Capita > 0.05
#
# P Value of Unemployment > 0.05
#
# P Value of Tertiary_Enrollment > 0.05
#
# P Value of Life_Expectancy > 0.05
#
# P Value of Population_Density > 0.05
#
# - R Squared: 0.03290000337671328
#
# - Adjusted R Squared: -0.014506859202859657
#
# - F-statistic: 0.6939924219091752
#
# - Model p-value: 0.6291448362136607
#
# - RMSE: 0.004872024178202524
#
# - MAE: 0.0028616407062963703
#
# This model explains roughly 3.29% of variance in Signatures Per Capita
#
# The model performs poorly and is insignificant as the p value is > 0.05
#
# GDP per Capita, Unemployment, Tertiary Enrollment, Life Expectancy and Population Density poorly explain variance in Signatures Per Capita in this model
#
# And due to the p value of the model > 0.05 it fails to reject H0 of Research Question 3

# %% [markdown]
# ### Linear Regression Model 3C - Successful Petitions

# %%
model_3c = joblib.load(model_path + "regressions/regression_model_3c.pkl")

print("=" * 100)
print("Linear Regression Model 3C - Successful Petitions")
print("=" * 100)
print(model_3c.summary())
print("\n")
# Out:
# ...
# Linear Regression Model 3C - Successful Petitions
# ...
#                               OLS Regression Results
# ...
# Dep. Variable:     Signatures_Per_Capita   R-squared:                       0.043
# Model:                               OLS   Adj. R-squared:                 -0.004
# Method:                    Least Squares   F-statistic:                    0.9187
# Date:                   Fri, 28 Aug 2026   Prob (F-statistic):              0.472
# Time:                           01:09:51   Log-Likelihood:                 422.35
# No. Observations:                    108   AIC:                            -832.7
# Df Residuals:                        102   BIC:                            -816.6
# Df Model:                              5
# Covariance Type:               nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Interpretations
#
# P Value of Media Literacy Index > 0.05
#
# P Value of Governance > 0.05
#
# P Value of Social Capital > 0.05
#
# P Value of Personal Freedom > 0.05
#
# P Value of Education > 0.05
#
# - R Squared: 0.04309154342080623
#
# - Adjusted R Squared: -0.003815733862487569
#
# - F-statistic: 0.9186536912078118
#
# - Model p-value: 0.4721203493276124
#
# - RMSE: 0.004846284886205672
#
# - MAE: 0.002891861952111684
#
# This model explains roughly 4.30% of variance in Signatures Per Capita
#
# The model performs poorly and is insignificant as the p value is > 0.05
#
# Media Literacy Index, Governance, Social Capital, Personal Freedom and Education poorly explain variance in signatures per capita in this model
#
# And due to the p value of the model > 0.05 it fails to reject H0 of Research Question 3

# %% [markdown]
# ## Log Linear Regressions 2: Signatures Per Capita
#
# Can socio-economic indicators explain participation rates?
#
# #### Hypotheses:
#
# H0
#
# Socio-economic indicators have no significant relationship with participation rates when participation is normalised by population
#
# H1
#
# Socio-economic indicators have a limited explanatory power when participation is normalised by population

# %% [markdown]
# ### Log Regression Model 2A - Signatures Per Capita

# %%
log_model_2a = joblib.load(model_path + "log_regressions/log_regression_model_2a.pkl")

print("=" * 100)
print("Log Regression Model 2A - Signatures Per Capita")
print("=" * 100)
print(log_model_2a.summary())
print("\n")
# Out:
# ...
# Log Regression Model 2A - Signatures Per Capita
# ...
#                                 OLS Regression Results
# ...
# Dep. Variable:     Log_Signatures_Per_Capita   R-squared:                       0.005
# Model:                                   OLS   Adj. R-squared:                  0.002
# Method:                        Least Squares   F-statistic:                     1.691
# Date:                       Fri, 28 Aug 2026   Prob (F-statistic):              0.185
# Time:                               01:09:51   Log-Likelihood:                 3336.7
# No. Observations:                        729   AIC:                            -6667.
# Df Residuals:                            726   BIC:                            -6654.
# Df Model:                                  2
# Covariance Type:                   nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Interpretations
#
# P value of GDP per Capita > 0.05
#
# P value of Unemployment > 0.05
#
# - R Squared: 0.004636729590890676
#
# - Adjusted R Squared: 0.0018946820140061105
#
# - F-statistic: 1.6909734280244413
#
# - Model p-value: 0.18506520407179067
#
# - RMSE: 0.0025119445991764067
#
# - MAE: 0.001184769190616739
#
# This model explains roughly 0.5% of variance in Log Signatures Per Capita
#
# The model performs poorly and is insignificant as the p value is > 0.05
#
# GDP per Capita and Unemployment poorly explain variance in log signatures per capita in this model
#
# And due to the p value of the model > 0.05 it fails to reject H0 of Research Question 2

# %% [markdown]
# ### Log Regression Model 2B - Signatures Per Capita

# %%
log_model_2b = joblib.load(model_path + "log_regressions/log_regression_model_2b.pkl")

print("=" * 100)
print("Log Regression Model 2B - Signatures Per Capita")
print("=" * 100)
print(log_model_2b.summary())
print("\n")
# Out:
# ...
# Log Regression Model 2B - Signatures Per Capita
# ...
#                                 OLS Regression Results
# ...
# Dep. Variable:     Log_Signatures_Per_Capita   R-squared:                       0.007
# Model:                                   OLS   Adj. R-squared:                 -0.000
# Method:                        Least Squares   F-statistic:                    0.9962
# Date:                       Fri, 28 Aug 2026   Prob (F-statistic):              0.419
# Time:                               01:09:52   Log-Likelihood:                 3337.6
# No. Observations:                        729   AIC:                            -6663.
# Df Residuals:                            723   BIC:                            -6636.
# Df Model:                                  5
# Covariance Type:                   nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Interpretations
#
# P Value of GDP_Per_Capita > 0.05
#
# P Value of Unemployment > 0.05
#
# P Value of Tertiary_Enrollment > 0.05
#
# P Value of Life_Expectancy > 0.05
#
# P Value of Population_Density > 0.05
#
# - R Squared: 0.006842129299557187
#
# - Adjusted R Squared: -2.6182392700357937e-05
#
# - F-statistic: 0.9961879434315946
#
# - Model p-value: 0.41904373569367603
#
# - RMSE: 0.0025091399301634173
#
# - MAE: 0.0011857260398192987
#
# This model explains roughly 0.68% of variance in Log Signatures Per Capita
#
# The model performs poorly and is insignificant as the p value is > 0.05
#
# R squared adjusted is way off
#
# GDP per Capita, Unemployment Tertiary Enrollment, LIfe Expectancy and Population Density poorly explain variance in Log Signatures Per Capita in this model
#
# And due to the p value of the model > 0.05 it fails to reject H0 of Research Question 2

# %% [markdown]
# ### Log Regression Model 2C - Signatures Per Capita

# %%
log_model_2c = joblib.load(model_path + "log_regressions/log_regression_model_2c.pkl")

print("=" * 100)
print("Log Regression Model 2C - Signatures Per Capita")
print("=" * 100)
print(log_model_2c.summary())
print("\n")
# Out:
# ...
# Log Regression Model 2C - Signatures Per Capita
# ...
#                                 OLS Regression Results
# ...
# Dep. Variable:     Log_Signatures_Per_Capita   R-squared:                       0.008
# Model:                                   OLS   Adj. R-squared:                  0.001
# Method:                        Least Squares   F-statistic:                     1.168
# Date:                       Fri, 28 Aug 2026   Prob (F-statistic):              0.323
# Time:                               01:09:52   Log-Likelihood:                 3338.0
# No. Observations:                        729   AIC:                            -6664.
# Df Residuals:                            723   BIC:                            -6636.
# Df Model:                                  5
# Covariance Type:                   nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Interpretations
#
# P Value of Media Literacy Index > 0.05
#
# P Value of Governance > 0.05
#
# P Value of Social Capital > 0.05
#
# P Value of Personal Freedom > 0.05
#
# P Value of Education > 0.05
#
# - R Squared: 0.00801376042212043
#
# - Adjusted R Squared: 0.0011535512964089278
#
# - F-statistic: 1.1681510396068742
#
# - Model p-value: 0.32318065080434116
#
# - RMSE: 0.002507657400850922
#
# - MAE: 0.001186076429221014
#
# This model explains roughly 0.80% of variance in Log Signatures Per Capita
#
# The model performs poorly and is insignificant as the p value is > 0.05
#
# Media Literacy Index, Governance, Social Capital, Personal Freedom and Education poorly explain variance in log signatures per capita in this model
#
# And due to the p value of the model > 0.05 it fails to reject H0 of Research Question 2

# %% [markdown]
# ## Log Linear Regressions 3: Signatures Per Capita (Successful ECI Petitions only)
#
# Can socio-economic indicators explain participation rates when the analysis is reduced to only successful Petitions?
#
# #### Hypotheses:
#
# H0
#
# Socio-economic indicators have no significant relationship with participation rates when participation is normalised by population
#
# H1
#
# Socio-economic indicators have a limited explanatory power when participation is normalised by population

# %% [markdown]
# ### Log Regression Model 3A - Successful Petitions

# %%
log_model_3a = joblib.load(model_path + "log_regressions/log_regression_model_3a.pkl")

print("=" * 100)
print("Log Regression Model 3A - Successful Petitions")
print("=" * 100)
print(log_model_3a.summary())
print("\n")
# Out:
# ...
# Log Regression Model 3A - Successful Petitions
# ...
#                                 OLS Regression Results
# ...
# Dep. Variable:     Log_Signatures_Per_Capita   R-squared:                       0.056
# Model:                                   OLS   Adj. R-squared:                  0.038
# Method:                        Least Squares   F-statistic:                     3.111
# Date:                       Fri, 28 Aug 2026   Prob (F-statistic):             0.0487
# Time:                               01:09:52   Log-Likelihood:                -144.73
# No. Observations:                        108   AIC:                             295.5
# Df Residuals:                            105   BIC:                             303.5
# Df Model:                                  2
# Covariance Type:                   nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Interpretations
#
# P value of GDP per Capita < 0.05
#
# P value of Unemployment > 0.05
#
# - R Squared: 0.055950103382827576
#
# - Adjusted R Squared: 0.03796820059011963
#
# - F-statistic: 3.1114673473552696
#
# - Model p-value: 0.0486670277477942
#
# - RMSE: 0.005177190340073621
#
# - MAE: 0.0024936934859960034
#
# This model explains roughly 5.6% of variance in Log Signatures Per Capita
#
# R squared adjusted isnt too far from R Squared
#
# The model performs moderately well and is significant as the p value is < 0.05
#
# GDP per Capita and Unemployment somewhat explain variance in log signatures per capita in this model
#
# And due to the p value of the model < 0.05 it it rejects th null hypothesis H0 of Research Question 3
#
# However I think I can still do better

# %% [markdown]
# ### Log Regression Model 3B - Successful Petitions

# %%
log_model_3b = joblib.load(model_path + "log_regressions/log_regression_model_3b.pkl")

print("=" * 100)
print("Log Regression Model 3B - Successful Petitions")
print("=" * 100)
print(log_model_3b.summary())
print("\n")
# Out:
# ...
# Log Regression Model 3B - Successful Petitions
# ...
#                                 OLS Regression Results
# ...
# Dep. Variable:     Log_Signatures_Per_Capita   R-squared:                       0.079
# Model:                                   OLS   Adj. R-squared:                  0.034
# Method:                        Least Squares   F-statistic:                     1.746
# Date:                       Fri, 28 Aug 2026   Prob (F-statistic):              0.131
# Time:                               01:09:52   Log-Likelihood:                -143.40
# No. Observations:                        108   AIC:                             298.8
# Df Residuals:                            102   BIC:                             314.9
# Df Model:                                  5
# Covariance Type:                   nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Interpretations
#
# P Value of GDP_Per_Capita < 0.05
#
# P Value of Unemployment > 0.05
#
# P Value of Tertiary_Enrollment > 0.05
#
# P Value of Life_Expectancy > 0.05
#
# P Value of Population_Density > 0.05
#
# - R Squared: 0.07884092051628089
#
# - Adjusted R Squared: 0.033686063678843636
#
# - F-statistic: 1.7460119694348162
#
# - Model p-value: 0.130835016837693
#
# - RMSE: 0.005136928131581428
#
# - MAE: 0.002472244863790585
#
# This model explains roughly 7.88% of variance in Log Signatures Per Capita
#
# The model performs poorly and is insignificant as the p value is > 0.05
#
# GDP per Capita, Unemployment, Tertiary Enrollment, Life Expectancy and Population Density poorly explain variance in Log Signatures Per Capita in this model
#
# And due to the p value of the model > 0.05 it fails to reject H0 of Research Question 3

# %% [markdown]
# ### Log Regression Model 3C - Successful Petitions

# %%
log_model_3c = joblib.load(model_path + "log_regressions/log_regression_model_3c.pkl")

print("=" * 100)
print("Log Regression Model 3C - Successful Petitions")
print("=" * 100)
print(log_model_3c.summary())
print("\n")
# Out:
# ...
# Log Regression Model 3C - Successful Petitions
# ...
#                                 OLS Regression Results
# ...
# Dep. Variable:     Log_Signatures_Per_Capita   R-squared:                       0.119
# Model:                                   OLS   Adj. R-squared:                  0.075
# Method:                        Least Squares   F-statistic:                     2.747
# Date:                       Fri, 28 Aug 2026   Prob (F-statistic):             0.0227
# Time:                               01:09:52   Log-Likelihood:                -141.02
# No. Observations:                        108   AIC:                             294.0
# Df Residuals:                            102   BIC:                             310.1
# Df Model:                                  5
# Covariance Type:                   nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Interpretations
#
# P Value of Media Literacy Index > 0.05
#
# P Value of Governance > 0.05
#
# P Value of Social Capital > 0.05
#
# P Value of Personal Freedom > 0.05
#
# P Value of Education > 0.05
#
# - R Squared: 0.11865974293610237
#
# - Adjusted R Squared: 0.07545678915846032
#
# - F-statistic: 2.746565513710546
#
# - Model p-value: 0.022729910301383778
#
# - RMSE: 0.005070833057544792
#
# - MAE: 0.0024192060488678717
#
# This model explains roughly 11.87% of variance in Log Signatures Per Capita
#
# The model performs quite well and is significant as the p value is < 0.05
#
# Media Literacy Index, Governance, Social Capital, Personal Freedom and Education explain variance pretty well somewhat in log signatures per capita in this model
#
# And due to the p value of the model < 0.05 it rejects the null hypothesis H0 of Research Question 3

# %% [markdown]
# ## Principal Component Analysis Regression Models
#
# #### Research Question 2:
#
# Can socio-economic indicators explain participation rates?
#
# PCA Linear Regressions Models:
#
# - PCA Linear Regression 01
# - PCA Log Linear Regression 01
#
#
# #### Research Question 3:
#
# Can socio-economic indicators explain participation rates when the analysis is reduced to only successful Petitions?
#
# PCA Linear Regressions Models:
#
# - PCA Linear Regression 02
# - PCA Log Linear Regression 02

# %% [markdown]
# ### PCA Regression 01 - Signatures Per Capita

# %%
pca_model_01 = joblib.load(model_path + "pca/pca_regression_model_01.pkl")

print("=" * 100)
print("PCA Regression 01 - Signatures Per Capita")
print("=" * 100)
print(pca_model_01.summary())
print("\n")
# Out:
# ...
# PCA Regression 01 - Signatures Per Capita
# ...
#                               OLS Regression Results
# ...
# Dep. Variable:     Signatures_Per_Capita   R-squared:                       0.009
# Model:                               OLS   Adj. R-squared:                  0.003
# Method:                    Least Squares   F-statistic:                     1.634
# Date:                   Fri, 28 Aug 2026   Prob (F-statistic):              0.164
# Time:                           01:09:52   Log-Likelihood:                 3331.5
# No. Observations:                    729   AIC:                            -6653.
# Df Residuals:                        724   BIC:                            -6630.
# Df Model:                              4
# Covariance Type:               nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Interpretations
#
# P Value of PC1 < 0.05
#
# P Value of PC2 > 0.05
#
# P Value of PC3 > 0.05
#
# P Value of PC4 > 0.05
#
# - R Squared: 0.008948581996408245
#
# - Adjusted R Squared: 0.003473159797493297
#
# - F-statistic: 1.6343181715159254
#
# - Model p-value: 0.16372794765893453
#
# - RMSE: 0.0025063747284414977
#
# - MAE: 0.0011896871180916825
#
# The PCA components while they flatten the dimensions of the country level variables very well
#
# They fail to effectively explain variance in Signatures Per Capita
#
#
# This model explains roughly 0.90% of variance in Signatures Per Capita
#
# The model performs poorly and is insignificant as the p value is > 0.05
#
# Thr Principal Components poorly explain variance in signatures per capita in this model
#
# And due to the p value of the model > 0.05 it fails to reject H0 of Research Question 2

# %% [markdown]
# ### PCA Regression 02 - Successful Petitions

# %%
pca_model_02 = joblib.load(model_path + "pca/pca_regression_model_02.pkl")

print("=" * 100)
print("PCA Regression 02 - Successful Petitions")
print("=" * 100)
print(pca_model_02.summary())
print("\n")
# Out:
# ...
# PCA Regression 02 - Successful Petitions
# ...
#                               OLS Regression Results
# ...
# Dep. Variable:     Signatures_Per_Capita   R-squared:                       0.068
# Model:                               OLS   Adj. R-squared:                  0.032
# Method:                    Least Squares   F-statistic:                     1.877
# Date:                   Fri, 28 Aug 2026   Prob (F-statistic):              0.120
# Time:                           01:09:52   Log-Likelihood:                 423.77
# No. Observations:                    108   AIC:                            -837.5
# Df Residuals:                        103   BIC:                            -824.1
# Df Model:                              4
# Covariance Type:               nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Interpretations
#
# P Value of PC1 > 0.05
#
# P Value of PC2 > 0.05
#
# P Value of PC3 < 0.05
#
# P Value of PC4 > 0.05
#
# - R Squared: 0.06794540152606832
#
# - Adjusted R Squared: 0.03174910643970208
#
# - F-statistic: 1.8771369103922644
#
# - Model p-value: 0.12005046917782466
#
# - RMSE: 0.004782934359889791
#
# - MAE: 0.002818238478091873
#
# Interpretations of the PCA Regression 02
#
# Using the successful only dataset
#
# Performs slightly better on the data when it only uses successful datasets
#
# This model explains roughly 0.90% of variance in Log Signatures Per Capita
#
# The Principal Components poorly explain variance in log signatures per capita in this model
#
# And due to the p value of the model > 0.05 it fails to reject H0 of Research Question 3

# %% [markdown]
# ### PCA Log Regression 01 - Signatures Per Capita

# %%
pca_log_model_01 = joblib.load(model_path + "pca/pca_log_regression_model_01.pkl")

print("=" * 100)
print("PCA Log Regression 01 - Signatures Per Capita")
print("=" * 100)
print(pca_log_model_01.summary())
print("\n")
# Out:
# ...
# PCA Log Regression 01 - Signatures Per Capita
# ...
#                                 OLS Regression Results
# ...
# Dep. Variable:     Log_Signatures_Per_Capita   R-squared:                       0.009
# Model:                                   OLS   Adj. R-squared:                  0.004
# Method:                        Least Squares   F-statistic:                     1.650
# Date:                       Fri, 28 Aug 2026   Prob (F-statistic):              0.160
# Time:                               01:09:52   Log-Likelihood:                 3338.4
# No. Observations:                        729   AIC:                            -6667.
# Df Residuals:                            724   BIC:                            -6644.
# Df Model:                                  4
# Covariance Type:                   nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Interpretations
#
# P Value of PC1 < 0.05
#
# P Value of PC2 > 0.05
#
# P Value of PC3 > 0.05
#
# P Value of PC4 > 0.05
#
# - R Squared: 0.008948581996408245
#
# - Adjusted R Squared: 0.003473159797493297
#
# - F-statistic: 1.6343181715159254
#
# - Model p-value: 0.16372794765893453
#
# - RMSE: 0.0025063747284414977
#
# - MAE: 0.0011896871180916825
#
# The PCA components while they flatten the dimensions of the country level variables very well
#
# They fail to effectively explain variance in Signatures Per Capita
#
#
# This model explains roughly 0.90% of variance in Signatures Per Capita
#
# The model performs poorly and is insignificant as the p value is > 0.05
#
# Thr Principal Components poorly explain variance in signatures per capita in this model
#
# And due to the p value of the model > 0.05 it fails to reject H0 of Research Question 2

# %% [markdown]
# ### PCA Log Regression 02 - Successful Petitions

# %%
pca_log_model_02 = joblib.load(model_path + "pca/pca_log_regression_model_02.pkl")

print("=" * 100)
print("PCA Log Regression 02 - Successful Petitions")
print("=" * 100)
print(pca_log_model_02.summary())
print("\n")
# Out:
# ...
# PCA Log Regression 02 - Successful Petitions
# ...
#                                 OLS Regression Results
# ...
# Dep. Variable:     Log_Signatures_Per_Capita   R-squared:                       0.134
# Model:                                   OLS   Adj. R-squared:                  0.100
# Method:                        Least Squares   F-statistic:                     3.987
# Date:                       Fri, 28 Aug 2026   Prob (F-statistic):            0.00477
# Time:                               01:09:52   Log-Likelihood:                -140.07
# No. Observations:                        108   AIC:                             290.1
# Df Residuals:                            103   BIC:                             303.5
# Df Model:                                  4
# Covariance Type:                   nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Interpretations
#
# P Value of PC1 < 0.05
#
# P Value of PC2 > 0.05
#
# P Value of PC3 > 0.05
#
# P Value of PC4 > 0.05
#
# - R Squared: 0.13406089249720887
#
# - Adjusted R Squared: 0.10043218929321696
#
# - F-statistic: 3.9865019975345106
#
# - Model p-value: 0.004769283252752825
#
# - RMSE: 0.005033326957621434
#
# - MAE: 0.0023905456709999665
#
# Using the successful only dataset
#
# Performs slightly better on the data when it only uses successful datasets
#
# This model explains roughly 13.4% of variance in Log Signatures Per Capita
#
# The Principal Components explain variance in log signatures per capita much better in this model
#
# And due to the p value of the model < 0.05 it rejects H0 of Research Question 3

# %% [markdown]
# ## Random Forest Regression Models
#
# #### Research Question 2:
#
# Can socio-economic indicators explain participation rates?
#
# Random Forest Regression Models:
#
# - Random Forest Regression 01
# - Random Forest Regression 03 (Log)
#
#
# #### Research Question 3:
#
# Can socio-economic indicators explain participation rates when the analysis is reduced to only successful Petitions?
#
# Random Forest Regression Models:
#
# - Random Forest Regression 02
# - Random Forest Regression 04 (Log)

# %% [markdown]
# ### Random Forest Regression 1:

# %% [markdown]
# ### Interpretations
#
# Variable Importance:
#
# Governance    0.272134
#
# Social_Capital    0.191004
#
# Education    0.181444
#
# Media_Literacy_Index    0.179679
#
# Personal_Freedom    0.175740
#
# - Training R Squared: 0.04922813204889165
# - Testing R Squared: -0.07909222283811013
#
#
# - Training RMSE: 0.0024028540927921753
# - Testing RMSE: 0.002820040252801016
#
#
# - Training MAE: 0.0011119336022151773
# - Testing MAE: 0.0014139492127252043
#
# This model explains roughly 4.92% of variance in Signatures Per Capita on the Training Data
#
# The R squared in the testing stage is way off
#
# The model performs performs moderately well on the training data but performs poorly on the test data
#
# This is likely due to overfitting of the model and possibly due to the fact that the master dataset includes unsuccessful petitions which have a higher degree of variability
#
# It also may be due to the fact that the test set is too small and lacking depth due to the dataset size, I tried testing this with greater training/test split but it gave similar results
#
# Due to the nature of the model failing in the test stage it fails to reject H0 of Research Question 2

# %% [markdown]
# ### Random Forest Regression 2:

# %% [markdown]
# ### Interpretations
#
# Variable  Importance:
#
# Education    0.277134
#
# Governance    0.196496
#
# Social_Capital    0.194966
#
# Media_Literacy_Index    0.186892
#
# Personal_Freedom    0.144511
#
# - Training R Squared: 0.31534851029799016
# - Testing R Squared: -0.8274511429093583
#
#
# - Training RMSE: 0.004418700392343369
# - Testing RMSE: 0.00392724872029864
#
#
# - Training MAE: 0.002557240372841035
# - Testing MAE: 0.0028604701476061213
#
# This model explains roughly 31.5% of variance in Signatures Per Capita on the Training Data
#
# The R squared in the testing stage is still quite off
#
# The model performs performs really well on the training data but performs poorly on the test data
#
# This is likely due to overfitting of the model and possibly due to the fact that it performs too well on the training data
#
# It also may be due to the fact that the test set is too small and lacking depth due to the dataset size, I tried testing this with greater training/test split but it gave similar results
#
# Its worth noting the significant improvement in the R Squared value when the successful dataset is used instead of the master dataset
#
# Due to the nature of the model failing in the test stage it fails to reject H0 of Research Question 3

# %% [markdown]
# ### Random Forest Regression 3:

# %% [markdown]
# ### Interpretations
#
# Variable  Importance:
#
# Governance    0.262364
#
# Social_Capital    0.192813
#
# Media_Literacy_Index    0.190171
#
# Personal_Freedom    0.178130
#
# Education    0.176522
#
# - Training R Squared: 0.04928580202222266
# - Testing R Squared: -0.07826862984385508
#
#
# - Training RMSE: 0.0023784304673813567
# - Testing RMSE: 0.002800325809094118
#
#
# - Training MAE: 0.001106432282272231
# - Testing MAE: 0.0014065081250862962
#
# This model explains roughly 4.92% of variance in Log Signatures Per Capita on the Training Data
#
# The R squared in the testing stage is quite off
#
# The model performs performs moderately well on the training data but performs poorly on the test data
#
# This is likely due to overfitting of the model and possibly due to the fact that the master dataset includes unsuccessful petitions which have a higher degree of variability
#
# It also may be due to the fact that the test set is too small and lacking depth due to the dataset size, I tried testing this with greater training/test split but it gave similar results
#
# Due to the nature of the model failing in the test stage it fails to reject H0 of Research Question 2

# %% [markdown]
# ### Random Forest Regression 4:

# %% [markdown]
# ### Interpretations
#
# Variable  Importance:
#
# Education    0.292899
#
# Social_Capital    0.189910
#
# Media_Literacy_Index    0.187669
#
# Governance    0.179556
#
# Personal_Freedom    0.149966
#
# - Training R Squared: 0.35527185267585726
# - Testing R Squared: -0.020709023648044278
#
#
# - Training RMSE: 0.6967857371665753
# - Testing RMSE: 1.1956937395653067
#
#
# - Training MAE: 0.5597502287089929
# - Testing MAE: 0.9554994180997841
#
# This model explains roughly 35.5% of variance in Log Signatures Per Capita on the Training Data
#
# The R squared in the testing stage is a little off but the closest of all 4 models
#
# This model performs the best of the 4 random forest models and the training R Squared is the highest of all the models so far in the project
#
# The model performs performs really well on the training data but performs poorly on the test data
#
# This is likely due to overfitting of the model and possibly due to the fact that it performs too well on the training data
#
# It also may be due to the fact that the test set is too small and lacking depth due to the dataset size, I tried testing this with greater training/test split but it gave similar results
#
# Its worth noting the significant improvement in the R Squared value when the successful dataset is used with the log transformed signatures per capita
#
# Due to the nature of the model failing in the test stage it fails to reject H0 of Research Question 3

# %% [markdown]
# ## Model Visualisation Comparison

# %% [markdown]
# ### Question 1 Models

# %%
q1_models = {
    "Model 1A": 0.09937624969017278,
    "Model 1B": 0.09937624969017278,
    "Model 1C": 0.10132061322787378
}

plt.figure(figsize=(11, 6))

plt.bar(q1_models.keys(), q1_models.values())

plt.title("Research Question 1: Model R-Squared Comparison")
plt.xlabel("Model")
plt.ylabel("R-Squared")

# add labels
for i, value in enumerate(q1_models.values()):
    if value >= 0:
        plt.text(i, value + 0.004, f"{value:.3f}", ha="center")
    else:
        plt.text(i, -0.035, f"{value:.3f}", ha="center")

# Limit negative y axis
plt.ylim(-0.05, 0.15)

plt.axhline(0, linewidth=0.8)

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Question 2 Models

# %%
q2_models = {
    "2A": 0.004540913652041678,
    "2B": 0.006762903327590886,
    "2C": 0.0079352755410812,
    "Log 2A": 0.004636729590890676,
    "Log 2B": 0.006842129299557187,
    "Log 2C": 0.00801376042212043,
    "PCA 01": 0.00903120714150063,
    "PCA Log 01": 0.00903120714150063,
    "RF 01": -0.07909222283811013,
    "RF 03 Log": -0.07826862984385508
}

plt.figure(figsize=(11, 6))

plt.bar(q2_models.keys(), q2_models.values())

plt.title("Research Question 2: Model R-Squared Comparison")
plt.xlabel("Model")
plt.ylabel("R-Squared")

# add labels
for i, value in enumerate(q2_models.values()):
    if value >= 0:
        plt.text(i, value + 0.004, f"{value:.3f}", ha="center")
    else:
        plt.text(i, -0.035, f"{value:.3f}", ha="center")

# Limit the y axis
plt.ylim(-0.05, 0.15)

plt.axhline(0, linewidth=0.8)

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Question 3 Models

# %%
q3_models = {
    "3A": 0.0028302050507570398,
    "3B": 0.03290000337671328,
    "3C": 0.04309154342080623,
    "Log 3A": 0.055950103382827576,
    "Log 3B": 0.07884092051628089,
    "Log 3C": 0.11865974293610237,
    "PCA 02": 0.06794540152606832,
    "PCA Log 02": 0.13406089249720887,
    "RF 02": -0.8274511429093583,
    "RF 04 Log": -0.020709023648044278
}

plt.figure(figsize=(11, 6))

plt.bar(q3_models.keys(), q3_models.values())

plt.title("Research Question 3: Model R-Squared Comparison")
plt.xlabel("Model")
plt.ylabel("R-Squared")

# add labels
for i, value in enumerate(q3_models.values()):
    if value >= 0:
        plt.text(i, value + 0.004, f"{value:.3f}", ha="center")
    else:
        plt.text(i, -0.035, f"{value:.3f}", ha="center")

# limit the y axis
plt.ylim(-0.05, 0.15)

plt.axhline(0, linewidth=0.8)

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Overall Observations:
#
# Best overall Models:
#
# #### Question 1 (Raw Signatures):
#
# - 1C: 10.1% explained variance
#
# - 1A: 9.9% explained variance
#
# - 1B: 9.9% explained variance
#
# #### Question 2 (Signatures Per Capita in Master):
#
# No models were able to achieve a Significant P value or High enough R Squared value, therefore failing to reject the null hypothesis
#
# #### Question 3 (Signatures Per Capita in Successful):
#
# - PCA Log Linear Regression Model 02: 13.4% Explained Variance
#
# - Log Linear Regression Model 3C: 11.8% Explained Variance
#
# - Log Linear Regression Model 3A: 5.6% Explained Variance
#
# The Random Forest Models get an honourable mention with the highest training R Squared values, but in the test stage they failed to obtain a high enough R Squared value
#
# Across all the models thusfar, I noticed that the log transformed model and the regular model counterparts for Question 2 (master Dataset) have similar R Squared numbers
#
# While the Question 3 Models paint a completely different story, with the Regular model showing a slightly improved R Squared and the Log Transformed Counterpart showing the strongest imporvement
#
# This means the log transformed models did little to improve explained variance in the Master Dataset, But a Huge Improvement in the Successful Dataset Question
#
# This further supports the notion that The Unsuccessful Petitions damage the overall predictability of Signatures per Capita and restricting it to only Successful Petitions proves that Signatures Per Capita can be explained to a limited extent by Country Level Socio-Economic Variables, especially when non linear models are employed and a log transformation is made to the Target Variable
#
# This is further supported by the fact that the strongest Reliable model so far was the PCA Log LInear Regression model on the Successful Dataset which managed to explain 13% of the variance in Signatures Per Capita
#
# This shows somewhat that in the case of the Master dataset, variability is too great among non successful petitions creating too much noise for the model to adequately predict signatures per capita for Question 2
#
# The dataset that is restricted to successful petitions is much more predictable, and the log transformed Signatures Per Capita works a lot better with the variables in each model
#
# In the case for Question 3, it has been successfully proved that variance in signatures per capita can be explained, this is something that The Interim Report had yet to discover as it had been previosuly concluded that Socio Economic Factors didnt contribute much to the analysis
#
# This analysis proves this is not the case, and after many analyses through different models this answer has been discovered
#
# The Cluster Analysis also helped to find additional non linear patterns in my analysis for predicting variance in signatures per capita across countries using socio-economic factors
#
# The Box Plots showed that each cluster had a variation in signatures per capita and the map showed similar patterns to the behaviour I expected from the countries from observing the petitions themselves
#
# The PCA plot showed clear clustering based on socio economic variables
